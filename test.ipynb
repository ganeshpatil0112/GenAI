# %%
#pip install requests
#pip install --upgrade certifi
#pip install pip-system-certs

# %%
pip install pip-system-certs

# %%
import requests
url = "https://api.euron.one/api/v1/euri/images/generations"

headers = {
"Content-Type": "application/json",
"Authorization": "Bearer euri-1f3025f0ddab44e290bf86bed48790c9f4fd1325a59b42e49701607ebb5b9546" # Replace with your actua
}

payload = {
    "prompt": "give me a image of newton holding wine in hand",
    "model": "black-forest-labs/FLUX. 1-schnel1",
    "n": 2,
    "size": "1024x1024",
    "quality": "standard",
    "response_format": "url",
    "style": "vivid"
}


response = requests.post(url, json=payload, headers=headers)

# Print the response (image URLs or error message
if response. status_code == 200:
    print("Image URL:")
    print (response. json())
else:
    print("Error:")
    print (response. status_code, response. text)
# Out:
# Error:
# 500 {"error":{"message":"404 Unable to access model black-forest-labs/FLUX. 1-schnel1. Please visit https://api.together.ai/models to view the list of supported models.","type":"internal_error","code":"internal_server_error"},"success":false,"statusCode":500}

# %%
import requests
from IPython.display import display, Image

url = "https://api.euron.one/api/v1/euri/images/generations"

headers = {
"Content-Type": "application/json",
"Authorization": "Bearer euri-1f3025f0ddab44e290bf86bed48790c9f4fd1325a59b42e49701607ebb5b9546"
}

payload = {
"prompt": "A beautiful sunset over mountains",
"model": "black-forest-labs/FLUX.1-schnell",
"n": 2,
"size": "1024x1024",
"quality": "standard",
"response_format": "url",
"style": "vivid"
}

response = requests.post(url, json=payload, headers=headers)


for item in response.json()['data']:
    image_url = item['url']
    resp = requests.get(image_url)
    if resp.ok:
        display(Image(data=resp.content))
    else:
        print(f"Failed to fetch image: {image_url} (status {resp.status_code})")

# Print the response (image URLs or error message
if response.status_code == 200:
    print("Image URL:")
    print(response.json())
else:
    print("Error:")
    print(response.status_code, response.text)
# Out:
# Image URL:
# {'created': 1754719311, 'data': [{'url': 'https://api.together.ai/shrt/PW0AXDu6RNIXeJME', 'revised_prompt': 'A beautiful sunset over mountains'}]}
